# %%
import numpy as np
import sys
PROJECT_PATH ='/home/joanna/Desktop/SIECI NEURONOWE/Sieci neuronowe/Laboratorium/perceptron'
sys.path.insert(0, PROJECT_PATH)

# %% [markdown]
# ### load data ###

# %%
from model.perceptron import SimplePerceptron, AdalinePerceptron
from utils import load_data
import os

unipolar_x, unipolar_y = load_data(os.path.join(PROJECT_PATH, 'data/unipolar_train.json'), logic_gate='AND')
# unipolar_ext_x, unipolar_ext_y = load_data(os.path.join(PROJECT_PATH, 'data/unipolar_ext_train.json'), logic_gate='AND')
# unipolar_x = np.concatenate((unipolar_x, unipolar_ext_x), axis=0)
# unipolar_y = np.concatenate((unipolar_y, unipolar_ext_y), axis=None)

bipolar_x, bipolar_y = load_data(os.path.join(PROJECT_PATH, 'data/bipolar_train.json'), logic_gate='AND')
# bipolar_ext_x, bipolar_ext_y = load_data(os.path.join(PROJECT_PATH, 'data/bipolar_ext_train.json'), logic_gate='AND')
# bipolar_x = np.concatenate((bipolar_x, bipolar_ext_x), axis=0)
# bipolar_y = np.concatenate((bipolar_y, bipolar_ext_y), axis=None)

from experiments import weights_init_range_experiment, alpha_lr_experiment
from utils import plot_data_with_std

# %% [markdown]
# # __SIMPLE PERCEPTRON__

# %% [markdown]
# #### weights changes - unipolar ####

# %%
weights, data = weights_init_range_experiment(SimplePerceptron, 'unipolar', 10, unipolar_x, unipolar_y)
plot_data_with_std(weights, data, 'Wartości zakresu inicjacji wag +/-', 'Liczba epok', filename='10', dirname='unipolar_w_range')

weights, data = weights_init_range_experiment(SimplePerceptron, 'unipolar', 50, unipolar_x, unipolar_y)
plot_data_with_std(weights, data, 'Wartości zakresu inicjacji wag +/-', 'Liczba epok', filename='50', dirname='unipolar_w_range')

weights, data = weights_init_range_experiment(SimplePerceptron, 'unipolar', 100, unipolar_x, unipolar_y)
plot_data_with_std(weights, data, 'Wartości zakresu inicjacji wag +/-', 'Liczba epok', filename='100', dirname='unipolar_w_range')

# %% [markdown]
# #### weight changes - bipolar ####

# %%
weights, data = weights_init_range_experiment(SimplePerceptron, 'bipolar', 10, bipolar_x, bipolar_y)
plot_data_with_std(weights, data, 'Wartości zakresu inicjacji wag +/-', 'Liczba epok', filename='10', dirname='bipolar_w_range', color='blue')

weights, data = weights_init_range_experiment(SimplePerceptron, 'bipolar', 50, bipolar_x, bipolar_y)
plot_data_with_std(weights, data, 'Wartości zakresu inicjacji wag +/-', 'Liczba epok', filename='50', dirname='bipolar_w_range', color='blue')

weights, data = weights_init_range_experiment(SimplePerceptron, 'bipolar', 100, bipolar_x, bipolar_y)
plot_data_with_std(weights, data, 'Wartości zakresu inicjacji wag +/-', 'Liczba epok', filename='100', dirname='bipolar_w_range', color='blue')

# %% [markdown]
# #### learning rate - unipolar ####

# %%
from experiments import alpha_lr_experiment
lr_values, data = alpha_lr_experiment(SimplePerceptron, 'unipolar', 10, unipolar_x, unipolar_y)
plot_data_with_std(lr_values, data, 'Wartości współczynnika uczenia', 'Liczba epok', filename='10', dirname='unipolar_lr')

lr_values, data = alpha_lr_experiment(SimplePerceptron, 'unipolar', 50, unipolar_x, unipolar_y)
plot_data_with_std(lr_values, data, 'Wartości współczynnika uczenia', 'Liczba epok', filename='50', dirname='unipolar_lr')

lr_values, data = alpha_lr_experiment(SimplePerceptron, 'unipolar', 100, unipolar_x, unipolar_y)
plot_data_with_std(lr_values, data, 'Wartości współczynnika uczenia', 'Liczba epok', filename='100', dirname='unipolar_lr')

# %% [markdown]
# #### learning rate - bipolar ####

# %%
lr_values, data = alpha_lr_experiment(SimplePerceptron, 'bipolar', 10, bipolar_x, bipolar_y)
plot_data_with_std(lr_values, data, 'Wartości współczynnika uczenia', 'Liczba epok', filename='10', dirname='bipolar_lr', color='blue')

lr_values, data = alpha_lr_experiment(SimplePerceptron, 'bipolar', 50, bipolar_x, bipolar_y)
plot_data_with_std(lr_values, data, 'Wartości współczynnika uczenia', 'Liczba epok', filename='50', dirname='bipolar_lr', color='blue')

lr_values, data = alpha_lr_experiment(SimplePerceptron, 'bipolar', 100, bipolar_x, bipolar_y)
plot_data_with_std(lr_values, data, 'Wartości współczynnika uczenia', 'Liczba epok', filename='100', dirname='bipolar_lr', color='blue')

# %% [markdown]
# #### activation function ####

# %%
from experiments import weights_init_range_experiment, alpha_lr_experiment
from utils import plot_compare_activation_fun

weights, data_w_uni = weights_init_range_experiment(SimplePerceptron, 'unipolar', 100, unipolar_x, unipolar_y)
weights, data_w_bi = weights_init_range_experiment(SimplePerceptron, 'bipolar', 100, bipolar_x, bipolar_y)
lr_values, data_lr_uni = alpha_lr_experiment(SimplePerceptron, 'unipolar', 100, unipolar_x, unipolar_y)
lr_values, data_lr_bi = alpha_lr_experiment(SimplePerceptron, 'bipolar', 100, bipolar_x, bipolar_y)

plot_compare_activation_fun(weights, data_w_uni, data_w_bi, 'Wartości zakresu inicjacji wag +/-', 'Liczba epok', 'f. unipolarna', 'f. bipolarna',
                           filename='w_range_100', dirname='fun_comparision')

plot_compare_activation_fun(lr_values, data_lr_uni, data_lr_bi, 'Wartości współczynnika uczenia', 'Liczba epok', 'f. unipolarna', 'f. bipolarna',
                           filename='lr_range_100', dirname='fun_comparision')

# %% [markdown]
# ### lr huge values ###

# %%
lr_values, data = alpha_lr_experiment(SimplePerceptron, 'unipolar', 100, unipolar_x, unipolar_y)
plot_data_with_std(lr_values, data, 'Wartości współczynnika uczenia powyżej 0.3', 'Liczba epok', filename='huge_100', dirname='unipolar_lr', color='green')

lr_values, data = alpha_lr_experiment(SimplePerceptron, 'bipolar', 100, bipolar_x, bipolar_y)
plot_data_with_std(lr_values, data, 'Wartości współczynnika uczenia powyżej 0.3', 'Liczba epok', filename='huge_100', dirname='bipolar_lr', color='blue')
# Out:
# {'W': array([0.69120082, 0.7174698 ]), 'bias': -1.085}
# {'W': array([2.85009595, 2.85141438]), 'bias': -1.78}

# %% [markdown]
# # __ADALINE PERCEPTRON__#

# %% [markdown]
# #### weights changes ####

# %%
weights, data = weights_init_range_experiment(AdalinePerceptron, 'bipolar', 10, bipolar_x, bipolar_y)
plot_data_with_std(weights, data, 'Wartości zakresu inicjacji wag +/-', 'Liczba epok', filename='10', dirname='adaline_w_range', color='red')

weights, data = weights_init_range_experiment(AdalinePerceptron, 'bipolar', 50, bipolar_x, bipolar_y)
plot_data_with_std(weights, data, 'Wartości zakresu inicjacji wag +/-', 'Liczba epok', filename='50', dirname='adaline_w_range', color='red')

weights, data = weights_init_range_experiment(AdalinePerceptron, 'bipolar', 100, bipolar_x, bipolar_y)
plot_data_with_std(weights, data, 'Wartości zakresu inicjacji wag +/-', 'Liczba epok', filename='100', dirname='adaline_w_range', color='red')

# %% [markdown]
# ### weight changes - more than <1.0,...>###

# %%
weights, data = weights_init_range_experiment(AdalinePerceptron, 'bipolar', 100, bipolar_x, bipolar_y)
plot_data_with_std(weights, data, 'Wartości zakresu inicjacji wag powyżej +/- 0.1', 'Liczba epok', filename='huge_w_100', dirname='adaline_w_range', color='red')

# %% [markdown]
# #### learning rate ####

# %%
lr_values, data = alpha_lr_experiment(AdalinePerceptron, 'bipolar', 10, bipolar_x, bipolar_y)
plot_data_with_std(lr_values, data, 'Wartości współczynnika uczenia', 'Liczba epok', filename='10', dirname='adaline_lr', color='red')

lr_values, data = alpha_lr_experiment(AdalinePerceptron, 'bipolar', 50, bipolar_x, bipolar_y)
plot_data_with_std(lr_values, data, 'Wartości współczynnika uczenia', 'Liczba epok', filename='50', dirname='adaline_lr', color='red')

lr_values, data = alpha_lr_experiment(AdalinePerceptron, 'bipolar', 100, bipolar_x, bipolar_y)
plot_data_with_std(lr_values, data, 'Wartości współczynnika uczenia', 'Liczba epok', filename='100', dirname='adaline_lr', color='red')

# %% [markdown]
# ### lr change - huge values ###

# %%
lr_values, data = alpha_lr_experiment(AdalinePerceptron, 'bipolar', 30, bipolar_x, bipolar_y)
plot_data_with_std(lr_values, data, 'Wartości współczynnika uczenia powyżej 0.3', 'Liczba epok', filename='huge_100', dirname='adaline_lr', color='red')
